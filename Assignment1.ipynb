# %% [markdown]
# Import package and data

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import plotly.express as px
import folium
from folium import plugins
from folium.plugins import HeatMap
import pandas as pd

df_crime = pd.read_csv('https://data.sfgov.org/api/views/tmnf-yvry/rows.csv')
# Out:
# (2129525, 35)

# %% [markdown]
# # **A1 Part 1: Visualizing patterns in the data**

# %% [markdown]
# **P1.1**: First create the week-day plots, the months, the 24-hour cycle, and the 168 hours of the week as barcharts (Week 2, Part 2).

# %% [markdown]
# **Week-day plots**

# %%
focuscrimes = set(['WEAPON LAWS', 'PROSTITUTION', 'DRIVING UNDER THE INFLUENCE', 'ROBBERY', 'BURGLARY', 'ASSAULT', 'DRUNKENNESS', 'DRUG/NARCOTIC', 'TRESPASS', 'LARCENY/THEFT',
                   'VANDALISM', 'VEHICLE THEFT', 'STOLEN PROPERTY', 'DISORDERLY CONDUCT'])
focuscrimes = list(focuscrimes)
df_focuscrimes = df_crime.where(df_crime.Category.isin(focuscrimes))

df_focuscrimes['Date'] = pd.to_datetime(df_focuscrimes['Date'], format="%m/%d/%Y")
df_focuscrimes['Time'] = pd.to_datetime(df_focuscrimes['Time'], format="%H:%M")
df_focuscrimes['Year'] = df_focuscrimes['Date'].dt.year
df_focuscrimes['Month'] = df_focuscrimes['Date'].dt.month
df_focuscrimes['Hour'] = df_focuscrimes['Time'].dt.hour
df_focuscrimes['168_Hour_of_week'] = df_focuscrimes['Date'].dt.dayofweek * 24 + (df_focuscrimes['Hour'] + 1)
df_focuscrimes['Day'] = df_focuscrimes['Date'].dt.day
df_focuscrimes['Minute'] = df_focuscrimes['Time'].dt.minute

for i, category in enumerate(focuscrimes):
    plt.subplot(7, 2, i+1)
    df = df_focuscrimes[df_focuscrimes.Category == category]
    df_count = df.groupby(df['DayOfWeek']).count()
    df_count['IncidntNum'][['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday','Saturday','Sunday']].plot(kind='bar', title = category, figsize=(20,50))
    
plt.subplots_adjust(hspace = 1)

# %% [markdown]
# **Comments**
#
# We can see that some types of crime have totally different rates in different week day, but some of them have the similiar rates in different week day. e.g. Prostitution have different rates in the week day, and Robbery have the almost same rate in different week day.

# %% [markdown]
# **Monthly data**

# %%
for i, category in enumerate(focuscrimes):
    plt.subplot(7, 2, i+1)
    df = df_focuscrimes[df_focuscrimes.Category == category]
    df_count = df.groupby(df['Month']).count()
    df_count['IncidntNum'].plot(kind='bar', title = category, figsize=(20,50))
    
plt.subplots_adjust(hspace = 0.6)

# %% [markdown]
# **Comments**
#
# We found that all types of crime have a tend. Crime rates are higher in winter than in summer.

# %% [markdown]
# **the 24-hour cycle**

# %%
for i, category in enumerate(focuscrimes):
    plt.subplot(7, 2, i+1)
    df = df_focuscrimes[df_focuscrimes.Category == category]
    df_count = df.groupby(df['Hour']).count()
    df_count['IncidntNum'].plot(kind='bar', title = category, figsize=(20,50))
    
plt.subplots_adjust(hspace = 0.6)

# %% [markdown]
# **Comments**
#
# The crime rates peak at night and fall in the morning arount 7.p.m. It's a sign that we need more police at night.

# %% [markdown]
# **the 168 hours of the week**

# %%
for i, category in enumerate(focuscrimes):
    plt.subplot(7, 2, i+1)
    df = df_focuscrimes[df_focuscrimes.Category == category]
    df_count = df.groupby(df['168_Hour_of_week']).count()
    df_count['IncidntNum'].plot(kind='bar', title = category, figsize=(20,50))
    plt.tick_params(axis='x',which='both',bottom=False,labelbottom=False)
    
plt.subplots_adjust(hspace = 0.6)

# %% [markdown]
# **Comments**
#
# We can have the same conclusion as before, different types of crime have different patterns in the week day, but in the 24-hours, some of crime have the similiar distribution.

# %% [markdown]
# **P1.2**: Next choose a crime type that you like and create a calendar plot (Week 2, Part 4). Don't forget to comment on patterns you observe.

# %%
# !pip install calplot
import calplot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 KB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for calplot: filename=calplot-0.1.7.5-py3-none-any.whl size=8122 sha256=1ab2bc4783a729d441a6b34a64d733374814bf59f3d4cc5e652bfaefcdb3e23d
#   Stored in directory: /root/.cache/pip/wheels/5d/df/bf/66802485190cac766fb1d55a4420b5f03730fa68475d401a5e
# Successfully built calplot
# ...

# %%
df = df_focuscrimes[df_focuscrimes.Category == 'DRUNKENNESS']
df_count = df.groupby(df['Date']).count()
calplot.calplot(df_count["IncidntNum"], cmap='YlGn', colorbar=False)
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.
# (<Figure size 720x1958.4 with 16 Axes>,
#  array([<AxesSubplot:ylabel='2003'>, <AxesSubplot:ylabel='2004'>,
#         <AxesSubplot:ylabel='2005'>, <AxesSubplot:ylabel='2006'>,
#         <AxesSubplot:ylabel='2007'>, <AxesSubplot:ylabel='2008'>,
#         <AxesSubplot:ylabel='2009'>, <AxesSubplot:ylabel='2010'>,
#         <AxesSubplot:ylabel='2011'>, <AxesSubplot:ylabel='2012'>,
#         <AxesSubplot:ylabel='2013'>, <AxesSubplot:ylabel='2014'>,
#         <AxesSubplot:ylabel='2015'>, <AxesSubplot:ylabel='2016'>,
#         <AxesSubplot:ylabel='2017'>, <AxesSubplot:ylabel='2018'>],
#        dtype=object))

# %% [markdown]
# **Comments**
#
# We choose DRUNKENNESS as the crime type and create a calender plot. We found that the crime rate incresed before 2013 and decresed after. The crime rate peaks at 2013, that is an interesting found.

# %% [markdown]
# **P1.3**:Finally, choose a different crime type and create a polar plot of its 24hour cycle (Week 2, Part 4). Again, don't forget to comment as you would in a figure text.

# %%
df = df_focuscrimes[df_focuscrimes.Category == 'ROBBERY']
df_count = df.groupby(df['Hour']).count()
df_count["IncidntNum"]

# set figure size
plt.figure(figsize=(20,10))

# plot polar axis
ax = plt.subplot(111, polar=True)

# remove grid
plt.axis('off')

# Set the coordinates limits
upperLimit = 100
lowerLimit = 30

# Compute max and min in the dataset
max = df_count["IncidntNum"].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * df_count.IncidntNum + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(df_count.IncidntNum)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(df_count.IncidntNum)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white")

labelPadding = 4

for bar, angle, height, label in zip(bars,angles, heights, df_count.index):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor")

# %% [markdown]
# **Comments**
#
# We choosed ROBBERY as the crime type to create a polar plot. And this plot can clearly shows that the crime rate is higher in the night than the day time.

# %% [markdown]
# # A1 Part 2: Dataviz questions

# %% [markdown]
# **P2.1** Mention 10 examples of ways we can encode data:
#
# **Answer:**
#
# The 10 ways mentioned is position, length, area, shape, color, angle, line weight, line ending, texture, pattern
# 1. Encoding data by positions: marking places on the map based on their latitude and longitude, x-axis and y-axis are the latitude and longitude of the bound of the area respectively.
# 2. Encoding data by length: plotting someone's height of each year, x-axis is the year, y axis-is the height of the years. It's a barchart.
# 3. Encoding data by area: marking the area where can fly the drone on the map of Copenhagen, x-axis and y-axis are the latitude and longitude of the bounds of the area respectively and color on internal area. It's an area plot.
# 4. Encoding data by shape: plotting the height and weight of the whole class, x-axis is the height and y-axis is the weight, using two different shape to represent the gender of students. It's a scatter plot.
# 5. Encoding data by color: plotting the popularity of different types of music during decade years, x-axis is the year and y-axis is the popularity level of the music, usint different color to represent the type of the music. It's a line plot.
# 6. Encoding data by angle: it's a pie chart. Plotting the percentage of daily expenses, and the angle represents the percentage of the item of daily expense.
# 7. Encoding data by line weight: plotting the social network of several classmates, the more frequently two classmates communicate, the thicker the connection line. It's a connected graph.
# 8. Encoding data by arrow on the end of the line: plotting the connection between a big family, adding the relationship on the arrow line. It's a directed graph.
# 9. Encoding data by texture: filling in textures representing different geographical features based on the area map.
# 10. Encoding data by pattern: marking the location of the hotel, restaurant and school on the map by using the pattern of hotel, restaurant and scholl.

# %% [markdown]
# **P2.2**;Are all encodings created equally? Why not? Can you think of an example from the previous lectures?
#
# **Answer:**
#
# No, they are not equally. Like the calendar heatmaps from the week2, it's encoding by the color intensity and it can highlight the trends and anomalies over time. Other types of plots can't clearly and directly represent three dimensional, i.e. months, day of week, level(color intensity), on one graph.

# %% [markdown]
# **P2.3**:Mention 3 encodings that are difficult for the human eye to parse. Can you find an example of a visualization online that uses one of those three?
#
# **Answer:**
#
# They are angle, area/size and color intensity. The example is: [Spatial Heat Map Example: Displays temperature across a world image with red being the highest and blue being the lowest degree in temperatures (5 April 2019)](https://upload.wikimedia.org/wikipedia/commons/e/e7/World_heat_map.png).

# %% [markdown]
# **P2.4**:Explain in your own words: What is the problem with pie-charts?
#
# **Answer:**
#
# 1. They are difficult to identify the tiny differents between attributes;
# 2. They are hard to compare the different pie-charts because the angles are the proportion of different whole;
# 3. They are not easy for people eyes to understand;
# 4. They might ignore the small but important part;
# 5. They need many lables to mark what they mean.

# %% [markdown]
# # A1 Part 3: Visualizing geodata using Plotly

# %% [markdown]
# **P3.1**:Based on your map and analysis, where should you park the car for it to be safest on a Sunday? And where's the worst place?

# %%
# !pip install plotly
import plotly.express as px
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df = df_focuscrimes[df_focuscrimes.Category == 'VEHICLE THEFT']
df_DayOfWeek = df.groupby('DayOfWeek')
#data of sunday of vehicle theft
crime_crount = list(df_DayOfWeek)[3][1].groupby("PdDistrict").count()
crime_crount["District"]=crime_crount.index
# Out:
#             PdId  IncidntNum  Incident Code  Category  Descript  DayOfWeek  \
# PdDistrict
# BAYVIEW     2322        2322           2322      2322      2322       2322
# CENTRAL     1506        1506           1506      1506      1506       1506
# INGLESIDE   2846        2846           2846      2846      2846       2846
# MISSION     2400        2400           2400      2400      2400       2400
# NORTHERN    2001        2001           2001      2001      2001       2001
# PARK        1328        1328           1328      1328      1328       1328
# RICHMOND    1366        1366           1366      1366      1366       1366
# SOUTHERN    1566        1566           1566      1566      1566       1566
# TARAVAL     1943        1943           1943      1943      1943       1943
# TENDERLOIN   356         356            356       356       356        356
#
#             Date  Time  Resolution  Address  ...  \
# PdDistrict                                   ...
# ...

# %%
from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/suneman/socialdata2022/main/files/sfpd.geojson') as response:
    counties = json.load(response)

fig = px.choropleth_mapbox(crime_crount, geojson=counties, locations='District', color='IncidntNum',
                           color_continuous_scale="Viridis",
                           range_color=(300, 3000),
                           mapbox_style="carto-positron",
                           zoom=11, center = {"lat": 37.7700, "lon": -122.4194},
                           opacity=0.5,
                           labels={'unemp':'unemployment rate'}
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Avoid the maps will not show up, we add the picture below![San01.png](data:image/png;base64,...)

# %% [markdown]
# **Comments**
#
# We have filltered the data for the crime **VEHICLE THEFT**, which is make sense to analyse where is safest place to parking. Futhermore, we have filltered the day for **Sunday** and count the Vehicle theft crime numbers to create the choropleth map of San Francisco. The least crime number is 356 and most one is 2846, so we set the color range from 300 to 3000.
#
# Based on the map above, we have conclued that the safest place for parking on Sunday is **TENDERLOIN**, and the worst place is **INGLESIDE**

# %% [markdown]
# **P3.2**: Using visualizatios can help us uncover powerful data-patterns. However, when designing visualizations, we need to be aware of several illusions that can lead viewers to misinterpret the data we are showing (i.e. perceptual errors):
#
# Try to change the range of data-values in the plot above. Is there a way to make the difference between district less evident?
#
# Why do you think perceptual errors are a problem? Try to think of a few examples.

# %%
fig = px.choropleth_mapbox(crime_crount, geojson=counties, locations='District', color='IncidntNum',
                           color_continuous_scale="Viridis",
                           range_color=(10, 100000),
                           mapbox_style="carto-positron",
                           zoom=11, center = {"lat": 37.7700, "lon": -122.4194},
                           opacity=0.5,
                           labels={'unemp':'unemployment rate'}
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# To avoid the map will not show up, we added the picture below![San02.png](data:image/png;base64,...)

# %% [markdown]
# **Comment**
#
# We changed the range of data-values from 300-3000 to 10-100000. In the polt above we can see than the difference between district less evident, all the district hae the purple color.
#
# Perceptual errors are a problem because people are easily deceived by intuition and do not pay attention to the details of the data. For example, when someone go to the supermarket, some products have obvious discount tags which really
# attract people's attention. Thus, these products will have good sales. However, there are some other similar products which have the better price and quanlity will be ingnored.

# %% [markdown]
# # A1 Part 4: Errors in the data

# %% [markdown]
# **P4.1**:In each of the 3 examples we listed during Week 4, describe in your own words how the data-errors I call attention to above can bias the binned versions of the data.
#
# **Answer:**
# **1.PROSTITUTION something surprising is going on on Thursday:**
#
# [That polt](https://raw.githubusercontent.com/suneman/socialdata2022/main/files/prostitution.png) That plot reveals that there is a general trend of being more arrests for prostitution on Thursdays than any other day. That may becasue, the police always recorded the PROSTITUTION crime in Thursday, or the department which for the PROSTITUTION crime recorded is busy in Thursday.
#
# **2.Time-record:**
#
# The reason for the segmented time recordings is most likely because of human errors, where the officers when documenting the crime have just rounded the time to the nearest hour or 15 minute interval. This does not mean that the crime not occur in the other time. It may caused by when the hunman recorded the crime is always the certain time of the hour, so it is a typical human noise.
#
# **3.Hall of Justice:**
#
# The Hall of Justice is not the place where the crime has been done, but th place where the crime has been reported. Becasue the sex offences always been reported by the victims themselves. And the Hall of Justice is the place where the victims reported the sex offences crime.

# %% [markdown]
# **P4.2**:Also, briefly mention how not noticing these errors can result in misconceptions about the underlying patterns of what's going on in San Francisco (and our modeling).
#
# **Answer:**
#
# If we not noticed these errors, we will make some mistakes in police deployment. e.g. Because the time-recorded errors, we will pay more attention in the certain time in a hour to look for the crime but ignore other time which crime really happened. And for the Hall of Justice error, we will deploy the police in the hall of justice to avoid the sex offences happened but make a mistake.

# %% [markdown]
# **P4.3**: Find your own example of human noise in the data and visualize it.

# %%
df = df_focuscrimes[df_focuscrimes.Category == 'DRIVING UNDER THE INFLUENCE']
heat_data = [[row['Y'],row['X']] for index, row in df.iterrows()]

# %%
import folium

map_hooray = folium.Map(location=[37.774940, -122.403715],
                  tiles = "Stamen Toner",
                    zoom_start = 18) 
HeatMap(heat_data).add_to(map_hooray)
map_hooray
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# We visulized the DRIVING UNDER THE INFLUENCE data in heatmaps(Ref: [Folium](https://www.kaggle.com/code/daveianhickey/how-to-folium-for-maps-heatmaps-time-data/notebook)).
#
# In order to avoid the heatmap will not show up, I attached the reuslt of visualizion below.
# ![heat.png](data:image/png;base64,...)

# %% [markdown]
# We found that a lot of DRIVING UNDER THE INFLUENCE happened in one point of Bruant street, the frequence is much bigger than others. However, the driving is an ongoing activity. A lot of DRIVING UNDER THE INFLUENCE crime happened in there just because there are often police stopping and checking here. Thus, it is a typically human noise.
